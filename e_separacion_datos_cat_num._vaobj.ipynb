# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importar datos
bn = pd.read_csv("Tablas\ r2.csv", sep= ',')
bn.head()
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# 0           1                      3.0              4.0              2.0
# 1           2                      3.0              2.0              4.0
# 2           3                      2.0              2.0              1.0
# 3           4                      4.0              4.0              3.0
# 4           5                      4.0              1.0              3.0
#
#     Age  DistanceFromHome  Education  JobLevel  MonthlyIncome  \
# 0  51.0               6.0        2.0       1.0       131160.0
# 1  31.0              10.0        1.0       1.0        41890.0
# 2  32.0              17.0        4.0       4.0       193280.0
# 3  38.0               2.0        5.0       3.0        83210.0
# 4  32.0              10.0        1.0       1.0        23420.0
#
#    NumCompaniesWorked  ...  mean_time     BusinessTravel  \
# 0                 1.0  ...       7.37      Travel_Rarely
# ...

# %%
#Se separa la variable objetivo del dataframe
y = bn[['Attrition']]

# %%
#Se separa la variables independientes del dataframe
X = bn.drop('Attrition', axis=1)
X.head()
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# 0           1                      3.0              4.0              2.0
# 1           2                      3.0              2.0              4.0
# 2           3                      2.0              2.0              1.0
# 3           4                      4.0              4.0              3.0
# 4           5                      4.0              1.0              3.0
#
#     Age  DistanceFromHome  Education  JobLevel  MonthlyIncome  \
# 0  51.0               6.0        2.0       1.0       131160.0
# 1  31.0              10.0        1.0       1.0        41890.0
# 2  32.0              17.0        4.0       4.0       193280.0
# 3  38.0               2.0        5.0       3.0        83210.0
# 4  32.0              10.0        1.0       1.0        23420.0
#
#    NumCompaniesWorked  ...  PerformanceRating  mean_time     BusinessTravel  \
# ...

# %%
#Se separan las variables categoricas
cat=X[['BusinessTravel','Department','Education','EducationField','Gender','JobLevel', 'JobRole', 'MaritalStatus','JobInvolvement','PerformanceRating', 'EnvironmentSatisfaction', 'JobSatisfaction',
       'WorkLifeBalance','StockOptionLevel','resignationReason','retirementType']]
cat.head()
# Out:
#       BusinessTravel              Department  Education EducationField  \
# 0      Travel_Rarely                   Sales        2.0  Life Sciences
# 1  Travel_Frequently  Research & Development        1.0  Life Sciences
# 2  Travel_Frequently  Research & Development        4.0          Other
# 3         Non-Travel  Research & Development        5.0  Life Sciences
# 4      Travel_Rarely  Research & Development        1.0        Medical
#
#    Gender  JobLevel                    JobRole MaritalStatus  JobInvolvement  \
# 0  Female       1.0  Healthcare Representative       Married             3.0
# 1  Female       1.0         Research Scientist        Single             2.0
# 2    Male       4.0            Sales Executive       Married             3.0
# 3    Male       3.0            Human Resources       Married             2.0
# 4    Male       1.0            Sales Executive        Single             3.0
#
#    PerformanceRating  EnvironmentSatisfaction  JobSatisfaction  \
# ...

# %%
# Se separan las variables numericas
num=bn.drop(cat,axis=1)
num.drop(columns=['Attrition','EmployeeID'],inplace=True)
num.head()
# Out:
#     Age  DistanceFromHome  MonthlyIncome  NumCompaniesWorked  \
# 0  51.0               6.0       131160.0                 1.0
# 1  31.0              10.0        41890.0                 0.0
# 2  32.0              17.0       193280.0                 1.0
# 3  38.0               2.0        83210.0                 3.0
# 4  32.0              10.0        23420.0                 4.0
#
#    PercentSalaryHike  TotalWorkingYears  TrainingTimesLastYear  \
# 0               11.0                1.0                    6.0
# 1               23.0                6.0                    3.0
# 2               15.0                5.0                    2.0
# 3               11.0               13.0                    5.0
# 4               12.0                9.0                    2.0
#
#    YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager  mean_time
# 0             1.0                      0.0                   0.0       7.37
# ...

# %%
# Transformación de la variable respuesta en dos clases ya que es categorica
# 1: Yes
# 0: No

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

print(y[0:5])

print(le.classes_)
# Out:
# [0 1 0 0 0]
# ['No' 'Yes']
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#Se convierte y a dataframe
y = pd.DataFrame(y)

# Se nombre la variable
y.rename(columns={0: 'Attrition'}, inplace=True)

# %%
#Se guardan los datos como csv
num.to_csv('Tablas\ num.csv', index=True)
cat.to_csv('Tablas\cat.csv', index=True)
y.to_csv('Tablas\y.csv', index=True)
